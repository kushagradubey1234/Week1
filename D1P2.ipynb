# %%
myList = [ {"name": "Kush", "age" : 23}, {"name":"Krishna", "age" : 20}, {"name":"Rohit", "age" : 21} ]
myList.sort(key = lambda x: x["age"])
print(myList)
# Out:
# [{'name': 'Krishna', 'age': 20}, {'name': 'Rohit', 'age': 21}, {'name': 'Kush', 'age': 23}]
