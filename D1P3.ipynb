# %%
#Explain the time complexity of checking for an element's existence in a list vs. a set.
"""
   A list is a mutable data structure and does not allow indexing by value due to which everytime when we have to look for an element's existence we need to iterate through each element linearly from the initial which takes 0(n) time.
   So for a list:
      Best case: O(1) {Element is present at the first place}
      Average case: O(n) {Since we need to iterate until the valule matches}
      Worst case: O(n) {When the element is at the last or does not exist}

   A set is unordered and it uses hashing for storing the element. Every time an element is added it finds the hash value using hash(x) function and calculates an index value for storing it in the hash table. This allows searching through index and we can directly search for the index by using hash value and that's why set is faster than list.
   For a set:
      Best case: O(1) {Element is present at the first place}
      Average case: O(1) {Since we can access the element directly using the hash value}
      Worst case: O(n) {When the element does not exist in the set}
"""
