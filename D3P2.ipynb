# %%
import pandas as pd

# %%
data = pd.read_csv("/content/sales_data_400_entries.csv")

# %%
data.head()
# Out:
#    Order_ID Region Product_Category Product_Name  Sales  Quantity
# 0         1  North      Electronics    Product_C  17049         8
# 1         2  South      Electronics    Product_E   6697        19
# 2         3   West      Electronics    Product_A   7140         7
# 3         4  South      Electronics    Product_E  14031        18
# 4         5   West        Furniture    Product_D  39618         9

# %%
data.pivot_table( values='Sales', index='Region', columns='Product_Category', aggfunc='sum',)
# Out:
# Product_Category  Clothing  Electronics  Furniture  Groceries
# Region
# East                621467       532356     464313     730498
# North              1041775       528418     586833     368252
# South               517775       685089     630827     682790
# West                698594       586615     745685     713010
