# %%
#What is the difference between merge() and join() in Pandas?
"""
1. merge() in pandas behaves exactly like SQL join while join() is majorly used for index based joining.
2. merge() is more flexible than join() as it supports all join types of SQL.
3. merge() uses INNER JOIN as default while join() uses LEFT JOIN by default.
4. merge() focuses on column based combining.
5. merge() provide multiple keys but join() has limited keys.
6. join() supports multiple dataframes at once.
"""
